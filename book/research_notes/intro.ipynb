# %% [markdown]
# # Research Notes
#
# <div class="nav-links">
#   <a href="../intro.html">About Me</a>
#   <a href="../publications.html">Publications</a>
#   <a href="../course_notes/my-teaching-philosophy.html">My Teaching</a>
#   <a href="./intro.html">Research Notes</a>
# </div>
#
# ---
#
# This section tracks ongoing research notes, derivations, and technical explorations.
#
# More topic-specific notes can be added under `research_notes/` as this section grows.

# %% [markdown]
# ## Manim Slides
#
# ```{eval-rst}
# .. manim-slides:: ../manim_anims/init.py:DDPMELBOOneScene
#     :hide_source:
#     :config_options: slide_number=true controls=false
#     :quality: low
# ```
