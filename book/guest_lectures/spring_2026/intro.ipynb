# %% [markdown]
# # VAEs to Diffusion Models with Live Code
#
# <div class="nav-links">
#   <a href="../../intro.html">About Me</a>
#   <a href="../../publications.html">Publications</a>
#   <a href="../../course_notes/my-teaching-philosophy.html">My Teaching</a>
#   <a href="../../research_notes/intro.html">Research Notes</a>
# </div>
#
# ---
#
# This section contains all invited guest lecture material for **Spring 2026 (UB)**.
#
# ## Lecture Summary
#
# 1. **Lecture 1:** Essence of Generative AI
# 2. **Lecture 2:** Deep mathematical derivation of ELBO for VAE models
# 3. **Lecture 3:** Placeholder (TBD)
# 4. **Lecture 4:** Placeholder (TBD)
